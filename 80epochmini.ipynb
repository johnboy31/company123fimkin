# %% [markdown]
# <a href="https://colab.research.google.com/github/johnboy31/company123fimkin/blob/main/80epochmini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-178-ga199480 Python-3.10.12 torch-2.0.1+cu118 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/107.7 GB disk)

# %%
# !unzip -q ../runs.zip -d ../

# %%
# Train YOLOv5s
# !python train.py --img 640 --batch 16 --epochs 85 --data drone_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=drone_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=85, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-178-ga199480 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# ...

# %%
# !python detect.py --weights runs/train/exp2/weights/last.pt --img 640 --conf 0.25 --source ../drone_video.mp4
# reads the video source to detect
# Out:
# detect: weights=['runs/train/exp2/weights/last.pt'], source=../drone_video.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-178-ga199480 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/1139) /content/drone_video.mp4: 384x640 1 drone, 254.5ms
# video 1/1 (2/1139) /content/drone_video.mp4: 384x640 1 drone, 251.0ms
# video 1/1 (3/1139) /content/drone_video.mp4: 384x640 1 drone, 249.4ms
# video 1/1 (4/1139) /content/drone_video.mp4: 384x640 (no detections), 240.9ms
# ...

# %%
from google.colab import files

# %%
# !zip -r /content/mini_project.zip /content/mini_project
# Out:
#   adding: content/mini_project/ (stored 0%)
#   adding: content/mini_project/yolov5/ (stored 0%)
#   adding: content/mini_project/yolov5/README.zh-CN.md (deflated 76%)
#   adding: content/mini_project/yolov5/LICENSE (deflated 66%)
#   adding: content/mini_project/yolov5/val.py (deflated 67%)
#   adding: content/mini_project/yolov5/.github/ (stored 0%)
#   adding: content/mini_project/yolov5/.github/ISSUE_TEMPLATE/ (stored 0%)
#   adding: content/mini_project/yolov5/.github/ISSUE_TEMPLATE/config.yml (deflated 45%)
#   adding: content/mini_project/yolov5/.github/ISSUE_TEMPLATE/bug-report.yml (deflated 60%)
#   adding: content/mini_project/yolov5/.github/ISSUE_TEMPLATE/question.yml (deflated 57%)
#   adding: content/mini_project/yolov5/.github/ISSUE_TEMPLATE/feature-request.yml (deflated 61%)
#   adding: content/mini_project/yolov5/.github/dependabot.yml (deflated 60%)
#   adding: content/mini_project/yolov5/.github/PULL_REQUEST_TEMPLATE.md (deflated 40%)
# ...
